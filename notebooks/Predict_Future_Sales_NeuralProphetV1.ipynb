# %% [markdown]
# https://www.kaggle.com/competitions/competitive-data-science-predict-future-sales/data?select=sales_train.csv

# %%
# %pip install neuralprophet
# %pip install matplotlib
# %pip install pandas
# Out:
# Requirement already satisfied: neuralprophet in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: captum>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (0.7.0)
# Requirement already satisfied: holidays>=0.41 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (0.63)
# Requirement already satisfied: kaleido==0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (0.2.1)
# Requirement already satisfied: matplotlib>=3.5.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (3.8.4)
# Requirement already satisfied: numpy<2.0.0,>=1.25.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (2.2.2)
# Requirement already satisfied: plotly>=5.13.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (5.24.1)
# Requirement already satisfied: pytorch-lightning>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (2.5.0.post0)
# Requirement already satisfied: tensorboard>=2.11.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (2.17.1)
# Requirement already satisfied: torch>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (2.4.0)
# Requirement already satisfied: torchmetrics>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from neuralprophet) (1.6.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from neuralprophet) (4.11.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from captum>=0.6.0->neuralprophet) (4.66.2)
# Requirement already satisfied: python-dateutil in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from holidays>=0.41->neuralprophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.5.3->neuralprophet) (24.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=2.0.0->neuralprophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=2.0.0->neuralprophet) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from plotly>=5.13.1->neuralprophet) (9.0.0)
# Requirement already satisfied: PyYAML>=5.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralprophet) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (2024.6.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralprophet) (0.11.9)
# Requirement already satisfied: absl-py>=0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (1.66.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (4.25.4)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (65.5.0)
# Requirement already satisfied: six>1.9 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from tensorboard>=2.11.2->neuralprophet) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (3.0.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0.0->neuralprophet) (3.15.4)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0.0->neuralprophet) (1.13.2)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0.0->neuralprophet) (3.3)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0.0->neuralprophet) (3.1.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (3.11.11)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.11.2->neuralprophet) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->torch>=2.0.0->neuralprophet) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (1.18.3)
# Requirement already satisfied: idna>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (3.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/sushantjoshi/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

from neuralprophet import NeuralProphet
import pandas as pd
import logging
import warnings

logging.getLogger('prophet').setLevel(logging.ERROR)
logging.getLogger('numexpr').setLevel(logging.ERROR)
logging.getLogger("cmdstanpy").disabled=True
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read the sales data into a dataframe

# %%
sales_df = pd.read_csv('data/dataset/sales_train.csv')
sales_df['date'] = pd.to_datetime(sales_df['date'], format='mixed')

# %% [markdown]
# ## Drop excess columns

# %%
# drop item_price and item_cnt_day
# sales_df = sales_df.drop(columns=['item_price', 'date_block_num'])

# %% [markdown]
# ## Read Items and Categories

# %%
# read item categories and items
items_df = pd.read_csv('data/dataset/items.csv')
categories_df = pd.read_csv('data/dataset/item_categories.csv')

# %% [markdown]
# ## Join Items to Categories

# %%
# merge item categories and items
items_df = pd.merge(items_df, categories_df, on='item_category_id')

# %% [markdown]
# ## Join Sales and Items

# %%
# combine sales and items
sales_df = pd.merge(sales_df, items_df, on='item_id')
sales_df.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-02-01               0       59    22154      999.00           1.0
# 1 2013-03-01               0       25     2552      899.00           1.0
# 2 2013-05-01               0       25     2552      899.00          -1.0
# 3 2013-06-01               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0
#
#                                   item_name  item_category_id  \
# 0                         ЯВЛЕНИЕ 2012 (BD)                37
# 1  DEEP PURPLE  The House Of Blue Light  LP                58
# 2  DEEP PURPLE  The House Of Blue Light  LP                58
# 3  DEEP PURPLE  Who Do You Think We Are  LP                58
# 4   DEEP PURPLE 30 Very Best Of 2CD (Фирм.)                56
#
#                     item_category_name
# 0                       Кино - Blu-Ray
# 1                       Музыка - Винил
# 2                       Музыка - Винил
# 3                       Музыка - Винил
# 4  Музыка - CD фирменного производства

# %%
# rename item_category_id to category
sales_df = sales_df.rename(columns={'item_category_id': 'category'})

# %% [markdown]
# # Drop Extra Columns

# %%
# Drop columns
sales_df = sales_df.drop(columns=['item_category_name', 'item_name', 'date_block_num', 'item_price'])

# %%
sales_df.head()

# # write csv file to disk
# sales_df.to_csv('data/dataset/sales_processed.csv', index=False)
# Out:
#         date  shop_id  item_id  item_cnt_day  category
# 0 2013-02-01       59    22154           1.0        37
# 1 2013-03-01       25     2552           1.0        58
# 2 2013-05-01       25     2552          -1.0        58
# 3 2013-06-01       25     2554           1.0        58
# 4 2013-01-15       25     2555           1.0        56

# %% [markdown]
# # Group the sales by categories and date

# %%
# Group the sales by date and category and sum up the sales from item_cnt_day column
sales_category_df = sales_df.groupby(['date', 'category'])['item_cnt_day'].sum().reset_index()
sales_category_df = sales_category_df.rename(columns={'date': 'ds', 'item_cnt_day': 'y'})

# %%
# Build prophet models for each category
models = {}

for category in sales_category_df['category'].unique():
    category_df = sales_category_df[sales_category_df['category'] == category]
    category_df = category_df[['ds', 'y']]
    
    # drop rows with negative values in y
    category_df = category_df[category_df['y'] >= 0]
    category_df = category_df.sort_values('ds')
    
    # Check if the dataframe has at least 2 non-NaN rows
    if category_df.dropna().shape[0] < 2:
        continue
    
    model = NeuralProphet()
    model.set_plotting_backend("plotly-static")
    model.fit(category_df)
    forecast = model.predict(category_df)

    # Plot positive forecasts only
    #forecast.loc[forecast['yhat'] < 0, 'yhat'] = 0
    models[category] = (model, forecast)

    # Label the plot with the category
    # model.plot(forecast).gca().set_title(category)

import matplotlib.pyplot as plt # type: ignore

# Number of plots
num_plots = len(models)

# Create a grid of subplots with 4 plots per row
fig, axes = plt.subplots(nrows=(num_plots + 3) // 4, ncols=4, figsize=(20, 5 * ((num_plots + 3) // 4)))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot each forecast in the grid
for i, (category, (model, forecast)) in enumerate(models.items()):
    model.plot(forecast, ax=axes[i])
    axes[i].set_title(category)

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Map shop_id from 1 to 10 to 0, 11 to 50 to 1, and 51 to 60 to 2
sales_df.loc[sales_df['shop_id'].between(1, 10), 'shop_id'] = 0
sales_df.loc[sales_df['shop_id'].between(11, 50), 'shop_id'] = 1
sales_df.loc[sales_df['shop_id'].between(51, 60), 'shop_id'] = 2
sales_df['shop_id'].unique()
# Out:
# array([2, 1, 0])

# %% [markdown]
# # Group the sales by Channel / store_id and date

# %%
# Group the sales by date and category and sum up the sales from item_cnt_day column
sales_channel_df = sales_df.groupby(['date', 'shop_id'])['item_cnt_day'].sum().reset_index()

# Build prophet models for each channel
models = {}

for channel in sales_channel_df['shop_id'].unique():
    channel_df = sales_channel_df[sales_channel_df['shop_id'] == channel]
    # rename date to ds and item_cnt_day to y
    channel_df = channel_df.rename(columns={'date': 'ds', 'item_cnt_day': 'y'})
    channel_df = channel_df[['ds', 'y']]
    
    # drop rows with negative values in y
    channel_df = channel_df[channel_df['y'] >= 0]
    channel_df = channel_df.sort_values('ds')
    
    # Check if the dataframe has at least 2 non-NaN rows
    if channel_df.dropna().shape[0] < 2:
        continue
    
    model = Prophet()
    model.fit(channel_df)
    forecast = model.predict(model.make_future_dataframe(periods=365))

    # Plot positive forecasts only
    forecast.loc[forecast['yhat'] < 0, 'yhat'] = 0
    models[channel] = (model, forecast)

    # Label the plot with the category
    model.plot(forecast).gca().set_title(channel)
